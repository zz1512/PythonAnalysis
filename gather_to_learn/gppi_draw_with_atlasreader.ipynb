# %%
from atlasreader import create_output
# Out:
# The Python package you are importing, AtlasReader, is licensed under the
# BSD-3 license; however, the atlases it uses are separately licensed under more
# restrictive frameworks.
# By using AtlasReader, you agree to abide by the license terms of the
# individual atlases. Information on these terms can be found online at:
# https://github.com/miykael/atlasreader/tree/master/atlasreader/data

# %%
file_name = 'H:\\metaphor\\gppi\\output_run4_reverse_rmfg\\second\\kj-yy\\Thresh_spmT_0001.nii'

# %%
create_output(file_name, cluster_extent = 9, voxel_thresh = 1,stat_plot_kws = {'black_bg':False},glass_plot_kws = {'black_bg':False})

# %%
from atlasreader import create_output
file_name = '/Users/liziyi/Downloads/rd/flxx1-moduation fdr_k5_rd.nii'
create_output(file_name, cluster_extent=5, voxel_thresh = 4.74, stat_plot_kws = {'black_bg':False},glass_plot_kws = {'black_bg':False})

# %%
from nilearn import plotting
from nilearn import datasets
fsaverage = datasets.fetch_surf_fsaverage()

# %%
plotting.plot_img_on_surf(file_name,
                          views=['lateral'],surf_mesh='fsaverage7', 
                          hemispheres=['right'], threshold=1,inflate=True, 
                          colorbar=True,bg_on_data=False)
# Out:
# (<Figure size 400x500 with 2 Axes>, [<Axes3D: >, <Axes: >])

# %%
plotting.plot_stat_map(
    file_name,
    threshold=1
)

# %%
view = plotting.view_img(stat_map, threshold=2.71)
# In a Jupyter notebook, if ``view`` is the output of a cell, it will
# be displayed below the cell
view
# Out:
# /Users/liziyi/opt/anaconda3/envs/searchlight/lib/python3.7/site-packages/numpy/core/fromnumeric.py:748: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
# ...

# %%
plotting.view_img(stat_map, threshold=2.71, cut_coords=[-42, -16, 52])
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
#     &lt;img id=&quot;colorMap&quot; class=&quot;hidden&quot; src=&quot;...&quot; alt=&quot;colormap&quot;&gt;
#     &lt;!-- another sprite image, with an overlay--&gt;
#     &lt;img id=&quot;overlayImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;overlay&quot;&gt;
#     &lt;/canvas&gt;
#   &lt;/div&gt;
#
# ...

# %%
plotting.plot_glass_brain(file_name, plot_abs=False, threshold = 2,display_mode='lzry')
